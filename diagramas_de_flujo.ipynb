# %% [markdown]
# <a href="https://colab.research.google.com/github/nperea75-gh/P5js/blob/gh-pages/diagramas_de_flujo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sumario**
#
# en el deseo  de seguir aportando a la construccion
# del conocimiento colectivo he decidido reconstruir los
# dos pdf´s que fueron conpartido en el grupo de python.
# se aceptan comentarios y sugerencias.
# gracias por leer.
#
#
# ---

# %% [markdown]
# **primer tablero**
#
# *ejercicio del estudiante*
#
#
# ![image.png](data:image/png;base64,...)
#
# Diagrama elaborado en pseint [pseint en sourceforge](https://sourceforge.net/projects/pseint/)

# %%
nombre = input ("ingrese su nombre ")
nota_1 = float ( input ("ingrese primera nota ") )
nota_2 = float ( input ("ingrese segunda  nota ") )
nota_3 = float ( input ("ingrese tercera nota ") )
promedio = (nota_1 + nota_2 + nota_3)/3
print (nombre , "tu promedio es" ,promedio)
# Out:
# ingrese su nombre Juan
# ingrese primera nota 4
# ingrese segunda  nota 5
# ingrese tercera nota 6
# Juan tu promedio es 5.0

# %% [markdown]
# **segundo tablero**
#
# clasifica persona segun la edad.
#
# ![image.png](data:image/png;base64,...)
#
#
# Diagrama elaborado en pseint [pseint en sourceforge](https://sourceforge.net/projects/pseint/)

# %%
# este codigo clasifica las edades segun se ingresen por teclado

edad=int(input("ingrese la edad "))
if edad<=0:
  print("ingrese edad valida")
if edad < 12:
  print("usted es un niño")
else:
  if edad < 18:
         print("usted es un adolescente")
  else:
    if edad < 60:
         print("usted es un adulto")
    else:
      print("usted es un anciano")
# Out:
# ingrese la edad 18
# usted es un adulto

# %% [markdown]
# se modifica el codigo anterior usando el "elif"  por recomendacion del compañero andres.

# %%
# este codigo clasifica las edades segun se ingresen por teclado

edad=int(input("ingrese la edad "))
if edad<=0:
  print("ingrese edad valida")
elif edad < 12:
  print("usted es un niño")
elif edad < 18:
  print("usted es un adolescente")
elif edad < 60:
  print("usted es un adulto")
elif edad > 60:
  print("usted es un anciano")
# Out:
# ingrese la edad 12
# usted es un adolescente

# %% [markdown]
# **Ejercicios propuestos ejercicio numero 1.**
#
# es par o impar ?
#
#
# Dado un número entero determinar si  si es par o impar.
#
#
# ![par o impar.png](data:image/png;base64,...)

# %%
#1. Dado un número entero, determinar si es par o impar

""" para resolver este problema se utiliza la operacion modulo (%) que nos devuelve el 
residuo de una division, en este caso se divide entre 2.
Ejemplo:  6/2 = 3 y queda 0 de resido; por lo tanto 6 es par.
         19/2 = 9 y queda de residuo 1; por lo tanto 19 es impar."""

num = int(input("escribe un numero: "))#input ingresar datos, si es numerico o literal el interprete lo ve como un texto.
                                       #int convierte el texto a un dato numerico entero.
if num % 2 == 0:                       #num % 2 nos da el residuo de la operacion num/2, ahora (num % 2 == 0) es una expresion que valida si residuo es cero o no.
  print ("el numero es par")           # if --> valida la condicion ( num % 2 == 0 ); si la condicion es verdadera se ejecuta la linea siguete ( impriir el numero es par), 
else: print ("el numero es impar")     # si es falsa no se ejecuta la linea anterior; sino la que esta despues de ella.
# Out:
# escribe un numero: 5
# el numero es impar

# %%
#1. Dado un número entero, determinar si es par o impar

""" modifico el codigo anterior para practicar el formateo de los string."""

par_o_impar = int(input("escribe un numero: "))
if par_o_impar % 2 == 0:                       
  print (f"el numero {par_o_impar} es par")        # se inserta la f antes de las comilla para que
else: print (f"el numero {par_o_impar} es impar")  # al imprimir el mensaje incluya la variabe {par_o_impar] en el    
                                                   # mensaje de salida.
# Out:
# escribe un numero: 23
# el numero 23 es impar

# %% [markdown]
# **ejercicios propuestos numero 2.**
#
# clasifica un triangulo segun el numero de lados.
#
# Solicitar la longitud de los tres lados de un triángulo, clasificarlos según el tamaño de sus Compruebe que se puede dibujar un triángulo, aplicando el teorema de la desigualdad del triángulo, el cual establece que la suma de dos lados del triángulo siempre es mayor que la medida del tercer lado, en caso de no cumplirlo sacar un mensaje.
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
# 2.  clasifica un triangulo segun el numero de lados.

""" Solicitar la longitud de los tres lados de un triángulo, clasificarlos según el tamaño
 de sus Compruebe que se puede dibujar un triángulo, aplicando el teorema de la desigualdad 
 del triángulo, el cual establece que la suma de dos lados del triángulo siempre es mayor que la
 medida del tercer lado, en caso de no cumplirlo sacar un mensaje.  """

x = int(1)
lado_a = int(input ("ingrese el primer lado "))
lado_b = int(input ("ingrese el segundo lado "))
lado_c = int(input ("ingrese el tercer lado "))

if lado_a > lado_b:
  x=lado_b; 
  lado_b = lado_a; 
  lado_a = x;

if lado_a > lado_c:
  x=lado_c; 
  lado_c = lado_a; 
  lado_a = x;

if lado_b > lado_c:
  x=lado_c; 
  lado_c = lado_b; 
  lado_b = x;
  
#suma_dos_lados = lado_a + lado_b

if lado_a + lado_b > lado_c:
  if lado_a == lado_b and lado_b == lado_c:
    print("es un triangulo equilatero")
  else:
    if lado_a != lado_b and lado_b != lado_c:
      print ("es un triangulo escaleno")
    else:
      print ("es un triangulo isoceles")
else:
  print("las medidas ingresadas no dibujan un triangulo")
# Out:
# ingrese el primer lado 5
# ingrese el segundo lado 5
# ingrese el tercer lado 5
# es un triangulo equilatero

# %% [markdown]
# **ejercicio propuesto 3**
#
# Pedir el salario básico y nombre de un empleado. Si el salario es superior
# a $500.000 se le descuenta el 1.5%, de lo contrario se le incrementa el 2%.
# *Imprimir* el nombre y nuevo salario del empleado.

# %%
#3. nomina

""""Pedir el salario básico y nombre de un empleado. Si el salario es superior a $500.000 se le descuenta el 1.5%, 
de lo contrario se le incrementa el 2%. Imprimir el nombre y nuevo salario del empleado."""

nombre_empleado = input ("ingrese nombre empleado ")
salario_empleado = int(input ("ingrese salario empleado "))
if salario_empleado > 500000:
  salario_empleado= int(salario_empleado * 0.985)
else:
  salario_empleado= int(salario_empleado * 1.02)
print (nombre_empleado, salario_empleado)
# Out:
# ingrese nombre empleado pedro
# ingrese salario empleado 200000
# pedro 204000

# %% [markdown]
# **ejercicio propuesto 4**
#
# Solicitar a una persona el nombre, edad, y género de una persona. Imprimir el nombre solo si es mujer y adulta, de lo contrario un mensaje “No cumple la condición”.

# %%
#4. es mujer?

"""Solicitar a una persona el nombre, edad, y género de una persona. 
Imprimir el nombre solo si es mujer y adulta, de lo contrario un mensaje
“No cumple la condición”."""


nombre_persona = input("ingrese nombre: ")
edad_persona = int(input("ingrese edad: "))
genero = input("ingrese m si es mujer; h si es hombre ")
if genero == "m" and edad_persona >= 18:
  print (nombre_persona)
else:
  print ("no cumple condicion")
# Out:
# ingrese nombre: marcos
# ingrese edad: 48
# ingrese m si es mujer; h si es hombre h
# no cumple condicion

# %% [markdown]
# **ejercicio propuesto 5**
#
# Dados el código (6 dígitos), nombre y tres notas de un estudiante. Calcular la definitiva y determinar qué carrera cursa, teniendo en cuenta que si el primer dígito del código es par estudia Ingenierías de lo contrario paramédicas; además un mensaje de sí aprobó o no la materia.

# %%
codigo_estudiante = input("Digite los seis numeros del codigo del estudiante ")
primer_digito = int (codigo_estudiante [0])
nombre_estudiante = input("Digite el nombre del estudiante ")
calificacion_1 = float (input("ingrese primera calificacion "))
calificacion_2 = float (input("ingrese primera calificacion "))
calificacion_3 = float (input("ingrese primera calificacion "))
promedio_calif = (calificacion_1 +  calificacion_2 +  calificacion_3 )/3 #formatear precision aqui o en la presentacion de los datos
if primer_digito%2 == 0:
  carrera = "ingenieria"
else:
  carrera = "paramedicas"
if promedio_calif >= 3.0: #formatear precision
  print(f" codigo {codigo_estudiante} {nombre_estudiante} con un promedio de: {promedio_calif} aprobo semestre carrera: {carrera}")
else:
  print(f" codigo {codigo_estudiante} {nombre_estudiante} con un promedio de: {promedio_calif} reprobo semestre carrera: {carrera}")

# %% [markdown]
# **ejercicio propuesto 6**
#
# Pedir tres números enteros (asuma que son diferentes), imprimirlos en orden ascendente

# %%
#6. ordena 3 numeros en orden ascendente.

x = int(1)
lado_a = int(input ("ingrese el primer lado "))
lado_b = int(input ("ingrese el segundo lado "))
lado_c = int(input ("ingrese el tercer lado "))

if lado_a > lado_b:
  x=lado_b; 
  lado_b = lado_a; 
  lado_a = x;

if lado_a > lado_c:
  x=lado_c; 
  lado_c = lado_a; 
  lado_a = x;

if lado_b > lado_c:
  x=lado_c; 
  lado_c = lado_b; 
  lado_b = x;
print (lado_a)
print (lado_b)
print (lado_c)
# Out:
# ingrese el primer lado 35
# ingrese el segundo lado 10
# ingrese el tercer lado 7
# 7
# 10
# 35

# %% [markdown]
# **ejercicio propuesto 7**
#
# Pedir la edad de una persona y clasificarla. Niños (0-12 años), Adolescentes (13-18 años), Adultos (Mayores de 18 hasta 60) y mayores de 60 Tercera Edad

# %%
#7. clasificador de edad por rango.

"""Pedir la edad de una persona y clasificarla. Niños (0-12 años), Adolescentes (13-18 años), 
Adultos (Mayores de 18 hasta 60) y mayores de 60 Tercera Edad."""

edad=int(input("ingrese la edad "))
if edad<=0:
  print("ingrese edad valida")
if edad > 0 and edad <= 12:
  print("usted es un niño")
elif edad > 13 and edad <= 18:
  print("usted es un adolescente")
elif edad > 19 and edad <= 60:
  print("usted es un adulto")
elif edad > 61:
  print("usted es un anciano")
# Out:
# ingrese la edad 20
# usted es un adulto

# %% [markdown]
# **ejercicio propuesto 8**
# Dado el siguiente algoritmo, realizar el Diagrama de flujo de datos (D.F.D) y hacer el TRACEO o PRUEBA de escritorio e indicar la SALIDA para los siguientes valores→ a=3, b=5.
# 1. INICIO
# 2. LEA a, b
# 3. c= a%b*2/3
# 4. SI (c!=0) ENTONCES
# IMPRIMIR a
# SINO IMPRIMIR b
# FINSI
# 5. IMPRIMIR “El valor calculado es: ”, c
# 6. FIN
# ---
#
# 2. a =3 b=5
# 3. 3%5 = 3 -> c = 2
# 4. print a -> a = 3
#
# el valor calculado es 3.

# %% [markdown]
# **ejercicio propuesto 9**
#
# Dado el siguiente algoritmo, realizar el D.F.D y hacer el TRACEO e indicar la salida.
# 1. INICIO
# 2. a=8, b=5
# 3. SI (a>=b) ENTONCES
# SI (b>0) ENTONCES
# IMPRIMIR a
# FINSI
# SINO IMPRIMIR b
# FINSI
# 4. FIN
# ---
#
# la salida del algoritmo es 8.

# %% [markdown]
# **ejercicio propuesto 12**
# En una tienda efectúan un descuento a los clientes dependiendo del monto de la compra. Calcular el descuento y el valor que tendría que pagar el cliente. El descuento se efectúa con base en el siguiente criterio:
# Si el monto es menor de $500.000, no hay descuento
# Si el monto está entre $500.000 y $1.000.000 inclusive el 5%
# Si el monto es superior a $1.000.000 y $7.000.000 inclusive el 11%
# Si el monto es superior a $7.000.000 y $15.000.000 inclusive el 18%
# Si el monto es mayor de $ 15.000.000 el 25%

# %% [markdown]
# **ejercicio propuesto 13**
# Haga un diagrama de flujo para calcular el precio del billete ida y vuelta en ferrocarril, conociendo la distancia del viaje de ida y el tiempo de estancia. Se sabe que además que si el número de días de estancia es superior a 7 y la distancia total (ida y vuelta) a recorrer es superior a 800 km, el billete tiene una reducción del 30%. El precio por kilómetro es $200.

# %%
kilometros_reales = int(input("ingrese los kilometro ida y vuelta: "))
estancia = int (input("ingrese los dias de estancia: "))
descuento = 70
precio_kilometro = 200
precio_viaje=1

if kilometros_reales > 800 and estancia > 7:
  precio_viaje= kilometros_reales*precio_kilometro*descuento/10
else:
  precio_viaje= kilometros_reales*precio_kilometro
print (f"el tiquete cuesta {precio_viaje}")
# Out:
# ingrese los kilometro ida y vuelta: 1000
# ingrese los dias de estancia: 10
# el tiquete cuesta 1400000.0

# %% [markdown]
# **ejercicio propuesto 14**
#
# Dado como dato el sueldo de un trabajador, considere un aumento del 10%, si el sueldo es superior a
#  500.000,  de un 12% en caso contrario. Imprimir el ingreso, el descuento y el sueldo neto a pagar al trabajador.

# %%
#14 sueldo

"""Dado como dato el sueldo de un trabajador, considere un aumento del 10%, si el sueldo es superior a 
 500.000,  de un 12% en caso contrario. Imprimir sueldo neto a pagar al trabajador."""

salario_trabajador=float(input("ingrese el salario del trabajador"))
if salario_trabajador>500000:
  salario_trabajador*=1.1
else:
  salario_trabajador*=1.12
print(f"el nuevo salario del trabajador es: {salario_trabajador:.0f}")
# Out:
# ingrese el salario del trabajador600000
# el nuevo salario del trabajador es: 660000

# %% [markdown]
# **ejercicio propuesto 15**
#
# Dado el peso (kilogramos) y la altura (m) de una persona, calcular su IMC y determinar su
# clasificación según la OMS.
# ![image.png](data:image/png;base64,...)

# %%
#15. imc

"""Dado el peso (kilogramos) y la altura (m) de una persona, 
calcular su IMC y determinar su clasificación según la OMS."""

peso = float(input("ingrese su peso en kilogramos "))
estatura = float(input("ingrese su estatura "))

imc = peso/estatura**2


if imc < 18.5:
  print (f"su imc es: {imc} usted esta bajo de peso. ")
elif  imc >= 18.6 and imc <=24.9:
  print (f"su imc es: {imc} usted esta normal.")
elif  imc >= 25 and imc <=29.9:
  print (f"su imc es: {imc} usted tiene sobrepeso.")
elif  imc >= 30 and imc <=34.5:
  print ("su imc es: %.2f usted tiene obesidad tipo I."%imc) #se usa el placeholder % para formatear la salida  del float imc
elif  imc >= 35 and imc <=39.9:
  print (f"su imc es: {imc:.2f} usted tiene obesidad tipo II.") #se usa el f-string para formatear la salida del float imc
elif  imc >= 40:
  print (f"su imc es: {imc} usted tiene obesidad tipo III.")
print (imc , "sin formato")
# Out:
# ingrese su peso en kilogramos 95
# ingrese su estatura 1.6
# su imc es: 37.11 usted tiene obesidad tipo II.
# 37.10937499999999 sin formato

# %%
#15. imc se hace un cambio al codigo anterior usando la  la funcion round para la salida del imc

"""Dado el peso (kilogramos) y la altura (m) de una persona, 
calcular su IMC y determinar su clasificación según la OMS."""

peso = float(input("ingrese su peso en kilogramos "))
estatura = float(input("ingrese su estatura "))

imc = round ((peso/estatura**2),2)
if imc < 18.5:
  print (f"su imc es: {imc} usted esta bajo de peso. ")
elif  imc >= 18.6 and imc <=24.9:
  print (f"su imc es: {imc} usted esta normal.")
elif  imc >= 25 and imc <=29.9:
  print (f"su imc es: {imc} usted tiene sobrepeso.")
elif  imc >= 30 and imc <=34.5:
  print ("su imc es: %.2f usted tiene obesidad tipo I.")
elif  imc >= 35 and imc <=39.9:
  print (f"su imc es: {imc} usted tiene obesidad tipo II.")
elif  imc <= 40:
  print (f"su imc es: {imc} usted tiene obesidad tipo III.")
# Out:
# ingrese su peso en kilogramos 75
# ingrese su estatura 1.75
# su imc es: 24.49 usted esta normal.

# %% [markdown]
# **ejercicio propuesto 16**
#
# Dado un año, hallar si este es bisiesto teniendo en cuenta un año es bisiesto si es divisible entre 4, excepto el último de cada siglo (aquel divisible por 100), salvo que este último sea divisible por 400.
# Es decir los años que sean divisibles por 4 serán bisiestos; pero no serán bisiestos si son divisibles entre 100 (como los años 1700, 1800, 1900 y 2100) excepto que sean divisibles por 400 (como los años 1600, 2000 ó 2400).

# %%
#16 año bisiesto

"""Dado un año, hallar si este es bisiesto teniendo en cuenta un año es bisiesto si es divisible entre 4,
 excepto el último de cada siglo (aquel divisible por 100), salvo que este último sea divisible por 400.
  Es decir los años que sean divisibles por 4 serán bisiestos;
 pero no serán bisiestos si son divisibles entre 100 (como los años 1700, 1800, 1900 y 2100) excepto que
  sean divisibles por 400 (como los años 1600, 2000 ó 2400)."""


year = int(input("ingrese el año que desea evaluar: "))
if (year>100 and year%100==0 and not year%400==0 or year<100 and not year%4==0 ): 
   print (f"el año {year} no es bisiesto")
else:
    print (f"el año {year} es bisiesto")
# Out:
# ingrese el año que desea evaluar: 1600
# el año 1600 es bisiesto

# %%
# reto 1 loteria genial.

# reto 1 loteria genial.

"""Conocidos dos números 𝑏 y 𝑛 (Con las características mencionadas
anteriormente) realizar un programa en Python que le permita al
concursante ingresar números entre 0 y 𝑏 (Incluídos los dos) hasta que
adivine el número 𝑛, además en cada intento, el programa debe
imprimir en consola lo siguiente:

○ Si el número ingresado por el concursante es mayor que 𝑛,
entonces el programa debe imprimir EXACTAMENTE las
siguientes palabras "¡Ups! Te pasaste" (Sin las comillas).------

○ Si el número ingresado por el concursante es menor a 𝑛,
entonces el programa debe imprimir EXACTAMENTE las
siguientes palabras "¡Ups! Estás por debajo" (Sin las
comillas)--------------

○ Si el número ingresado por el concursante es igual a 𝑛, entonces
el programa debe imprimir EXACTAMENTE las siguientes
palabras "¡LO LOGRASTE! Usaste 𝑥 intentos" (Sin las
comillas).------

donde 𝑥 denota la cantidad de intentos que hizo el
concursante para poder adivinar.

○ Si el número ingresado por el concursante es menor o mayor que
0 y 𝑏 respectivamente, entonces el programa debe imprimir
EXACTAMENTE las siguientes palabras s "¡Te saliste del
intervalo!" (No cuenta como intento).
"""
import random

# seteo de variables reqetidas
x = 0 # contador de numero de intentos.
n = random.randint(0,20) #numero secreto
b = random.randint(21,30) #rango de posible respuesta
end=True
# -- se inicia el ciclo de adivinanza
while end:
  n_concursante = int(input ("ingresa un numero: "))
  if n_concursante < 0 or n_concursante > b:
    print("¡Te saliste del intervalo!")
  elif n_concursante == n:
    x+=1
    end=False
  elif n_concursante > n:
    x+=1
    print("¡Ups! Te pasaste") 
  elif n_concursante < n:
    x+=1
    print("¡Ups! Estás por debajo")
print ("")
print("**************************************")
print(f"*   ¡LO LOGRASTE! Usaste {𝑥} intentos  *")
print("**************************************")
# Out:
# ingresa un numero: 15
# ¡Ups! Te pasaste
# ingresa un numero: 6
# ¡Ups! Estás por debajo
# ingresa un numero: 9
# ¡Ups! Estás por debajo
# ingresa un numero: 10
# ¡Ups! Estás por debajo
# ingresa un numero: 12
# ¡Ups! Estás por debajo
# ingresa un numero: 13
# ¡Ups! Estás por debajo
# ingresa un numero: 14
#
# **************************************
# *   ¡LO LOGRASTE! Usaste 7 intentos  *
# **************************************
